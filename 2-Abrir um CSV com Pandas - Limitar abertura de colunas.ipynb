# %%
import os
import pandas as pd

# Extrai coluna de texto do dataframe
df = pd.read_csv(os.path.join("data", "news.csv"))

# Converte o texto em lowercase
df['title'] = df['title'].str.lower()
resultado = df.head()[['publisher', 'title']]
print(resultado)
# Out:
#       publisher                                              title
# 0      Livemint  fed's charles plosser sees high bar for change...
# 1  IFA Magazine  us open: stocks fall after fed official hints ...
# 2  IFA Magazine  fed risks falling 'behind the curve', charles ...
# 3     Moneynews  fed's plosser: nasty weather has curbed job gr...
# 4        NASDAQ  plosser: fed may have to accelerate tapering pace

# %%
df
# Out:
#      id                                              title  \
# 0     2  fed's charles plosser sees high bar for change...
# 1     3  us open: stocks fall after fed official hints ...
# 2     4  fed risks falling 'behind the curve', charles ...
# 3     5  fed's plosser: nasty weather has curbed job gr...
# 4     6  plosser: fed may have to accelerate tapering pace
# ..  ...                                                ...
# 95   97  mcdonald's sales slip as americans' eating hab...
# 96   98  five guys, chipotle continue to take bites out...
# 97   99  mcdonald's reports lower us sales amid bitter ...
# 98  100                     mcdonald's not lovin' us sales
# 99  101  mcdonald's reports a 0.3 percent drop in febru...
#
#                                                   url  \
# 0   http://www.livemint.com/Politics/H2EvwJSK2VE6O...
# 1   http://www.ifamagazine.com/news/us-open-stocks...
# 2   http://www.ifamagazine.com/news/fed-risks-fall...
# 3   http://www.moneynews.com/Economy/federal-reser...
# 4   http://www.nasdaq.com/article/plosser-fed-may-...
# ..                                                ...
# 95  http://www.dailyfinance.com/2014/03/10/mcdonal...
# 96  http://www.courierpress.com/news/2014/mar/10/f...
# 97  http://www.nj.com/business/index.ssf/2014/03/b...
# 98  http://www.newsledge.com/mcdonalds-lovin-u-s-s...
# 99  http://www.benzinga.com/news/earnings/14/03/43...
#
#                       publisher category                          story  \
# 0                      Livemint        b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# 1                  IFA Magazine        b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# 2                  IFA Magazine        b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# 3                     Moneynews        b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# 4                        NASDAQ        b  ddUyU0VZz0BRneMioxUPQVP6sIxvM
# ..                          ...      ...                            ...
# 95                 DailyFinance        b  d4lvRcSzuglGdFMmqvT6ZGcG8vDlM
# 96  Evansville Courier \& Press        b  d4lvRcSzuglGdFMmqvT6ZGcG8vDlM
# 97              The Star-Ledger        b  d4lvRcSzuglGdFMmqvT6ZGcG8vDlM
# 98               The News Ledge        b  d4lvRcSzuglGdFMmqvT6ZGcG8vDlM
# 99                     Benzinga        b  d4lvRcSzuglGdFMmqvT6ZGcG8vDlM
#
#                 hostname      timestamp
# 0       www.livemint.com  1394470371207
# 1    www.ifamagazine.com  1394470371550
# 2    www.ifamagazine.com  1394470371793
# 3      www.moneynews.com  1394470372027
# 4         www.nasdaq.com  1394470372212
# ..                   ...            ...
# 95  www.dailyfinance.com  1394471389602
# 96  www.courierpress.com  1394471389786
# 97            www.nj.com  1394471389954
# 98     www.newsledge.com  1394471390131
# 99      www.benzinga.com  1394471390541
#
# [100 rows x 8 columns]
